# %%
# ABC abstract base class that defines the interface for a shape
# we will use this to define the interface for our shape classes
import sys
from pathlib import Path

from providers.base import LLMProvider


class Shape(LLMProvider):
    def generate(self, prompt: str, top_p: float, top_k: int) -> str:
        raise NotImplementedError("Subclasses must implement the generate method")
        pass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 import sys
#       4 from pathlib import Path
# ----> 6 from providers.base import LLMProvider
#       9 class Shape(LLMProvider):
#      10     def generate(self, prompt: str, top_p: float, top_k: int) -> str:
#
# ModuleNotFoundError: No module named 'providers'

# %%
from model import MessageRequest, Message, MessageRole

request = MessageRequest(
    messages=[
        Message(role=MessageRole.USER, content="classify the ticket"),  
        Message(role=MessageRole.ASSISTANT, content="Sure! Please provide the ticket details for classification.")
    ],
    top_p=0.9,
    max_new_tokens=100,
    top_k=50,
    temperature=0.2
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from model import MessageRequest, Message, MessageRole
#       3 request = MessageRequest(
#       4     messages=[
#       5         Message(role=MessageRole.USER, content="classify the ticket"),
#    (...)
#      11     temperature=0.2
#      12 )
#
# File c:\Users\workstation\OneDrive - Elshorouk Academy\Desktop\Depi\llm\model.py:21
#      15     content: str
#      16     content: str
#      20 @dataclass(frozen=True)
# ---> 21 class MessageRequest:
#      22     messages: list[Message]
#      23     top_p: float | None = None
#
# File c:\Users\workstation\.conda\envs\env3.10\lib\dataclasses.py:1175, in dataclass.<locals>.wrap(cls)
#    1174 def wrap(cls):
# -> 1175     return _process_class(cls, init, repr, eq, order, unsafe_hash,
# ...
