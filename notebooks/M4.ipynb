# %%
import dotenv
from groq import Groq
from dotenv import load_dotenv
from OpenAI import OpenAI
dotenv.load_dotenv()  # Load environment variables from .env file   
import os
client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/groq/v1"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 from groq import Groq
#       3 from dotenv import load_dotenv
# ----> 4 from OpenAI import OpenAI
#       5 dotenv.load_dotenv()  # Load environment variables from .env file
#       6 import os
#
# ModuleNotFoundError: No module named 'OpenAI'

# %%
response = client.generate_response("Explain the importance of fast language models")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = client.generate_response("Explain the importance of fast language models")
#       2 print(response)
#
# AttributeError: 'Groq' object has no attribute 'generate_response'

# %%
from llm.config import LLMConfig
from llm.client import LLMClient
client = LLMClient(config=LLMConfig(), provider="groq")
client.generate_response("   Explain the importance of fast language models")
